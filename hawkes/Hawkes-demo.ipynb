# %%
# %matplotlib inline

# %%
# %run -i simPointProcess.py
# Out:
# ECOS 2.0.4 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -2.418e+01  +3e+02  8e-01  2e-01  1e+00  1e+00    ---    ---    0  0  - |  -  -
#  1  -1.363e+01  -2.933e+01  +1e+02  5e-01  2e-01  8e-01  5e-01  0.6266  2e-01   1  1  1 |  3  2
#  2  -5.103e-01  -8.205e+00  +6e+01  3e-01  8e-02  4e-01  2e-01  0.9791  4e-01   1  1  1 |  6  0
#  3  +1.104e+01  +7.730e+00  +2e+01  1e-01  3e-02  2e-01  8e-02  0.6266  5e-02   1  1  1 |  2  2
#  4  +2.117e+01  +2.093e+01  +1e+00  1e-02  2e-03  2e-02  5e-03  0.9791  5e-02   1  1  1 |  2  0
#  5  +2.119e+01  +2.113e+01  +4e-01  3e-03  6e-04  4e-03  1e-03  0.7833  7e-02   1  1  1 |  2  1
#  6  +2.140e+01  +2.138e+01  +9e-02  7e-04  1e-04  1e-03  3e-04  0.7833  9e-03   1  1  1 |  1  1
#  7  +2.140e+01  +2.140e+01  +4e-02  3e-04  6e-05  4e-04  1e-04  0.6266  6e-02   1  1  1 |  2  2
#  8  +2.141e+01  +2.141e+01  +9e-03  6e-05  1e-05  9e-05  3e-05  0.7833  1e-02   2  1  1 |  1  1
#  9  +2.141e+01  +2.141e+01  +3e-03  3e-05  5e-06  4e-05  1e-05  0.6266  5e-02   2  1  1 |  2  2
# 10  +2.141e+01  +2.141e+01  +8e-04  6e-06  1e-06  8e-06  3e-06  0.7833  9e-03   2  1  1 |  1  1
# 11  +2.141e+01  +2.141e+01  +3e-04  2e-06  5e-07  3e-06  1e-06  0.6266  5e-02   1  0  0 |  2  2
# 12  +2.141e+01  +2.141e+01  +7e-05  5e-07  1e-07  7e-07  2e-07  0.7833  1e-02   2  0  0 |  1  1
# 13  +2.141e+01  +2.141e+01  +3e-05  2e-07  4e-08  3e-07  9e-08  0.6266  5e-02   1  0  0 |  2  2
# 14  +2.141e+01  +2.141e+01  +6e-06  5e-08  1e-08  7e-08  2e-08  0.7833  9e-03   1  0  0 |  1  1
# 15  +2.141e+01  +2.141e+01  +2e-06  2e-08  4e-09  3e-08  8e-09  0.6266  5e-02   1  0  0 |  2  2
# 16  +2.141e+01  +2.141e+01  +6e-07  4e-09  9e-10  6e-09  2e-09  0.7833  9e-03   0  0  0 |  1  1
# 17  +2.141e+01  +2.141e+01  +2e-07  2e-09  3e-10  2e-09  7e-10  0.6266  5e-02   0  0  0 |  2  2
# 18  +2.141e+01  +2.141e+01  +5e-08  4e-10  8e-11  5e-10  2e-10  0.7833  9e-03   0  0  0 |  1  1
#
# OPTIMAL (within feastol=3.9e-10, reltol=2.4e-09, abstol=5.0e-08).
# Runtime: 0.003051 seconds.
#
# error_alpha = 0.07813245871409602, error_lambda_0 = -0.06858886610476989

# %%
print('alpha_opt = {}, alpha_true = {}'.format(alpha_opt.value, alpha_0))
# Out:
# alpha_opt = 0.578132458714096, alpha_true = 0.5

# %%
print('lambda_opt = {}, lambda_true = {}'.format(lambda_opt.value, lambda_0))
# Out:
# lambda_opt = 0.9314111338952301, lambda_true = 1
