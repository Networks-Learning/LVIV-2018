# %%
# %matplotlib inline

# %%
# %run -i simPointProcess.py
# Out:
# ECOS 2.0.4 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -2.246e+01  +3e+02  7e-01  1e-01  1e+00  1e+00    ---    ---    0  0  - |  -  -
#  1  -1.811e+00  -1.447e+01  +1e+02  5e-01  6e-02  7e-01  4e-01  0.6266  1e-01   1  1  1 |  2  2
#  2  +2.030e+01  +1.445e+01  +4e+01  3e-01  3e-02  3e-01  2e-01  0.9791  4e-01   1  1  1 |  6  0
#  3  +3.353e+01  +3.216e+01  +1e+01  7e-02  6e-03  7e-02  4e-02  0.7833  9e-03   1  1  1 |  1  1
#  4  +3.828e+01  +3.795e+01  +2e+00  2e-02  1e-03  2e-02  8e-03  0.7833  9e-03   1  1  1 |  1  1
#  5  +3.880e+01  +3.873e+01  +5e-01  4e-03  3e-04  4e-03  2e-03  0.7833  1e-02   1  1  1 |  1  1
#  6  +3.905e+01  +3.903e+01  +1e-01  1e-03  8e-05  1e-03  5e-04  0.7833  5e-02   1  1  1 |  2  1
#  7  +3.907e+01  +3.907e+01  +5e-02  4e-04  3e-05  4e-04  2e-04  0.6266  5e-02   2  1  1 |  2  2
#  8  +3.908e+01  +3.908e+01  +1e-02  1e-04  8e-06  1e-04  4e-05  0.7833  1e-02   2  1  1 |  1  1
#  9  +3.908e+01  +3.908e+01  +3e-03  3e-05  2e-06  3e-05  1e-05  0.7833  5e-02   2  1  1 |  2  1
# 10  +3.909e+01  +3.909e+01  +1e-03  1e-05  8e-07  1e-05  4e-06  0.6266  5e-02   1  1  1 |  2  2
# 11  +3.909e+01  +3.909e+01  +3e-04  2e-06  2e-07  3e-06  1e-06  0.7833  1e-02   1  0  1 |  1  1
# 12  +3.909e+01  +3.909e+01  +1e-04  1e-06  8e-08  1e-06  4e-07  0.6266  5e-02   1  0  0 |  2  2
# 13  +3.909e+01  +3.909e+01  +2e-05  2e-07  2e-08  2e-07  9e-08  0.7833  1e-02   2  0  0 |  1  1
# 14  +3.909e+01  +3.909e+01  +9e-06  9e-08  7e-09  1e-07  4e-08  0.6266  5e-02   1  0  0 |  2  2
# 15  +3.909e+01  +3.909e+01  +2e-06  2e-08  2e-09  2e-08  8e-09  0.7833  9e-03   1  0  0 |  1  1
# 16  +3.909e+01  +3.909e+01  +8e-07  8e-09  6e-10  9e-09  3e-09  0.6266  5e-02   0  0  0 |  2  2
# 17  +3.909e+01  +3.909e+01  +2e-07  2e-09  1e-10  2e-09  7e-10  0.7833  9e-03   0  0  0 |  1  1
#
# OPTIMAL (within feastol=1.8e-09, reltol=4.9e-09, abstol=1.9e-07).
# Runtime: 0.002714 seconds.
#
# error_alpha = -0.27043140219284834, error_lambda_0 = 0.3302568640867547

# %%
print('alpha_opt = {}, alpha_true = {}'.format(alpha_opt.value, alpha_0))
# Out:
# alpha_opt = 0.22956859780715166, alpha_true = 0.5

# %%
print('lambda_opt = {}, lambda_true = {}'.format(lambda_opt.value, lambda_0))
# Out:
# lambda_opt = 1.3302568640867547, lambda_true = 1
